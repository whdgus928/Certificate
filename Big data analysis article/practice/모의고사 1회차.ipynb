# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/bank/train.csv')

# %%
df.head()
# Out:
#       ID  age         job  marital  education default  balance housing loan  \
# 0  13829   29  technician   single   tertiary      no    18254      no   no
# 1  22677   26    services   single  secondary      no      512     yes  yes
# 2  10541   30  management   single  secondary      no      135      no   no
# 3  13689   41  technician  married    unknown      no       30     yes   no
# 4  11304   27      admin.   single  secondary      no      321      no  yes
#
#     contact  day month  campaign  pdays  previous poutcome   y
# 0  cellular   11   may         2     -1         0  unknown  no
# 1   unknown    5   jun         3     -1         0  unknown  no
# 2  cellular   14   aug         2     -1         0  unknown  no
# 3  cellular   10   jul         1     -1         0  unknown  no
# 4   unknown    2   sep         1     -1         0  unknown  no

# %%
df.describe()
# Out:
#                  ID           age        balance           day      campaign  \
# count  12870.000000  12870.000000   12870.000000  12870.000000  12870.000000
# mean   16434.500000     41.091142    1483.774437     15.641103      2.659130
# std     3715.393317     11.305560    3311.055181      8.368983      2.863507
# min    10000.000000     18.000000   -6847.000000      1.000000      1.000000
# 25%    13217.250000     32.000000     102.000000      8.000000      1.000000
# 50%    16434.500000     39.000000     515.000000     16.000000      2.000000
# 75%    19651.750000     49.000000    1591.750000     21.000000      3.000000
# max    22869.000000     95.000000  102127.000000     31.000000     43.000000
#
#               pdays      previous
# count  12870.000000  12870.000000
# mean      45.555478      0.688967
# std      104.449411      2.049696
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
df.shape
# Out:
# (12870, 17)

# %%
#Q1
(df.age//10*10).value_counts().index[0]
# Out:
# 30

# %%
#Q2
(df.age//10*10).value_counts().values[0]
# Out:
# 5056

# %%
#Q3
len(df[(df['housing']=='yes')&(df['age']>=25)&(df['age']<29)])
# Out:
# 504

# %%
#Q5
df5=df[df['balance']>=df['balance'].mean()].sort_values('ID',ascending=False)

# %%
df5[:100]['balance'].mean()
# Out:
# 3473.73

# %%
#Q6
df[['day','month']].value_counts().index[0]
# Out:
# (15, 'may')

# %%
df[['age','balance']].corr()
# Out:
#               age   balance
# age      1.000000  0.101987
# balance  0.101987  1.000000

# %%
df
# Out:
#           ID  age         job  marital  education default  balance housing  \
# 0      13829   29  technician   single   tertiary      no    18254      no
# 1      22677   26    services   single  secondary      no      512     yes
# 2      10541   30  management   single  secondary      no      135      no
# 3      13689   41  technician  married    unknown      no       30     yes
# 4      11304   27      admin.   single  secondary      no      321      no
# ...      ...  ...         ...      ...        ...     ...      ...     ...
# 12865  14023   47  technician  married  secondary      no     1167     yes
# 12866  17259   31     unknown  married  secondary      no      111      no
# 12867  15200   37  unemployed   single   tertiary      no     1316     yes
# 12868  13775   42  management  married   tertiary      no      479     yes
# 12869  20137   24    services   single  secondary      no        0      no
#
# ...

# %%
import pandas as pd
train= pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/bank/train.csv')
test= pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/bank/test.csv')
submission= pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/bank/submission.csv')

display(train.head())
display(test.head())
display(submission.head())
# Out:
#       ID  age         job  marital  education default  balance housing loan  \
# 0  13829   29  technician   single   tertiary      no    18254      no   no
# 1  22677   26    services   single  secondary      no      512     yes  yes
# 2  10541   30  management   single  secondary      no      135      no   no
# 3  13689   41  technician  married    unknown      no       30     yes   no
# 4  11304   27      admin.   single  secondary      no      321      no  yes
#
#     contact  day month  campaign  pdays  previous poutcome   y
# 0  cellular   11   may         2     -1         0  unknown  no
# 1   unknown    5   jun         3     -1         0  unknown  no
# 2  cellular   14   aug         2     -1         0  unknown  no
# 3  cellular   10   jul         1     -1         0  unknown  no
# 4   unknown    2   sep         1     -1         0  unknown  no
#       ID  age          job   marital  education default  balance housing loan  \
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12870 entries, 0 to 12869
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         12870 non-null  int64
#  1   age        12870 non-null  int64
#  2   job        12870 non-null  int8
#  3   marital    12870 non-null  object
#  4   education  12870 non-null  object
#  5   default    12870 non-null  object
#  6   balance    12870 non-null  int64
#  7   housing    12870 non-null  object
#  8   loan       12870 non-null  object
#  9   contact    12870 non-null  object
#  10  day        12870 non-null  int64
#  11  month      12870 non-null  object
#  12  campaign   12870 non-null  int64
#  13  pdays      12870 non-null  int64
#  14  previous   12870 non-null  int64
#  15  poutcome   12870 non-null  object
#  16  y          12870 non-null  object
# dtypes: int64(7), int8(1), object(9)
# memory usage: 1.6+ MB

# %%
train['job']=train['job'].astype('category').cat.codes
train['marital']=train['marital'].astype('category').cat.codes
train['education']=train['education'].astype('category').cat.codes
train['default']=train['default'].astype('category').cat.codes
train['housing']=train['housing'].astype('category').cat.codes
train['loan']=train['loan'].astype('category').cat.codes
train['contact']=train['contact'].astype('category').cat.codes
train['month']=train['month'].astype('category').cat.codes
train['poutcome']=train['poutcome'].astype('category').cat.codes

test['job']=test['job'].astype('category').cat.codes
test['marital']=test['marital'].astype('category').cat.codes
test['education']=test['education'].astype('category').cat.codes
test['default']=test['default'].astype('category').cat.codes
test['housing']=test['housing'].astype('category').cat.codes
test['loan']=test['loan'].astype('category').cat.codes
test['contact']=test['contact'].astype('category').cat.codes
test['month']=test['month'].astype('category').cat.codes
test['poutcome']=test['poutcome'].astype('category').cat.codes

# %%
from sklearn.preprocessing import minmax_scale
train['balance']=minmax_scale(train['balance'])
test['balance']=minmax_scale(test['balance'])

# %%
train.drop('ID',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\user\Desktop\VS code\빅데이터 분석기사\모의고사 1회차.ipynb 셀 18 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/user/Desktop/VS%20code/%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B8%B0%EC%82%AC/%EB%AA%A8%EC%9D%98%EA%B3%A0%EC%82%AC%201%ED%9A%8C%EC%B0%A8.ipynb#Y100sZmlsZQ%3D%3D?line=0'>1</a> train.drop('ID',axis=1,inplace=True)
#
# File c:\Users\user\anaconda3\envs\baek\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
train
# Out:
#        age  job  marital  education  default   balance  housing  loan  \
# 0       29    9        2          2        0  0.230339        0     0
# 1       26    7        2          1        0  0.067530        1     1
# 2       30    4        2          1        0  0.064070        0     0
# 3       41    9        1          3        0  0.063107        1     0
# 4       27    0        2          1        0  0.065777        0     1
# ...    ...  ...      ...        ...      ...       ...      ...   ...
# 12865   47    9        1          1        0  0.073540        1     0
# 12866   31   11        1          1        0  0.063850        0     0
# 12867   37   10        2          2        0  0.074908        1     0
# 12868   42    4        1          2        0  0.067227        1     0
# 12869   24    7        2          1        0  0.062832        0     0
#
#        contact  day  month  campaign  pdays  previous  poutcome    y
# ...

# %%
test
# Out:
#          ID  age  job  marital  education  default   balance  housing  loan  \
# 0     53608   32    4        2          2        0  0.255153        0     0
# 1     51055   25    7        2          1        0  0.066094        0     0
# 2     52573   46    1        1          1        0  0.080986        1     0
# 3     50458   39    4        0          1        0  0.054045        0     0
# 4     52272   31    7        2          2        0  0.079348        0     0
# ...     ...  ...  ...      ...        ...      ...       ...      ...   ...
# 4286  50332   47    0        1          1        0  0.061579        0     0
# 4287  51293   33    9        1          1        0  0.055362        0     0
# 4288  54023   40    0        1          1        0  0.094578        1     0
# 4289  53775   39    1        1          1        0  0.092859        0     0
# 4290  51945   46    6        1          0        0  0.054012        0     0
#
# ...

# %%
X
# Out:
#        age  job  marital  education  default   balance  housing  loan  \
# 0       29    9        2          2        0  0.230339        0     0
# 1       26    7        2          1        0  0.067530        1     1
# 2       30    4        2          1        0  0.064070        0     0
# 3       41    9        1          3        0  0.063107        1     0
# 4       27    0        2          1        0  0.065777        0     1
# ...    ...  ...      ...        ...      ...       ...      ...   ...
# 12865   47    9        1          1        0  0.073540        1     0
# 12866   31   11        1          1        0  0.063850        0     0
# 12867   37   10        2          2        0  0.074908        1     0
# 12868   42    4        1          2        0  0.067227        1     0
# 12869   24    7        2          1        0  0.062832        0     0
#
#        contact  day  month  campaign  pdays  previous
# 0            0   11      8         2     -1         0
# ...

# %%
X=train[train.columns[:15]]
y=train[['y']]

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier()
model.fit(X,y)
model.score(X,y)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_84164\1942600078.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(X,y)
# 1.0

# %%
model.predict_proba(test)
# Out:
# array([[0.28, 0.72],
#        [0.19, 0.81],
#        [0.89, 0.11],
#        ...,
#        [0.77, 0.23],
#        [0.4 , 0.6 ],
#        [0.9 , 0.1 ]])

# %%
id=test['ID'].pop

# %%
test=test.drop('ID',axis=1)

# %%
test
# Out:
#       age  job  marital  education  default   balance  housing  loan  contact  \
# 0      32    4        2          2        0  0.255153        0     0        0
# 1      25    7        2          1        0  0.066094        0     0        0
# 2      46    1        1          1        0  0.080986        1     0        2
# 3      39    4        0          1        0  0.054045        0     0        2
# 4      31    7        2          2        0  0.079348        0     0        2
# ...   ...  ...      ...        ...      ...       ...      ...   ...      ...
# 4286   47    0        1          1        0  0.061579        0     0        1
# 4287   33    9        1          1        0  0.055362        0     0        0
# 4288   40    0        1          1        0  0.094578        1     0        0
# 4289   39    1        1          1        0  0.092859        0     0        0
# 4290   46    6        1          0        0  0.054012        0     0        0
#
# ...
